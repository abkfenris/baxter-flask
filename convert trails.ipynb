# %%
from fiona import collection
from shapely.geometry import mapping, shape

# %%
from baxter import create_app, db

# %%
from baxter.models import Trail

# %%
app = create_app('default')

# %%
# %save 'trail_maker' 9
# Out:
# The following commands were written to file `trail_maker.py`:
# def trail_maker(trail):
#     if trail['properties']['SkiTrail'] == 'Y':
#         skitrail = True
#     else:
#         skitrail = False
#
#     if trail['properties']['Display1'] == 'Y':
#         display = True
#     else:
#         display = False
#
#     if trail['properties']['PubShare'] == 'Y':
#         pubshare = True
#     else:
#         pubshare = False
#
#     if trail['properties']['Display_WU'] == 'Y':
#         display_wu = True
#     else:
#         display_wu = False
#
#     if trail['properties']['Display_WN'] == 'Y':
#         display_wn = True
#     else:
#         display_wn = False
#     t = Trail(geom=shape(trail['geometry']),
#               use_type=trail['properties']['USE_TYPE'],
#               comments=trail['properties']['COMMENTS'],
#               tid=trail['properties']['TID'],
#               skitrail=skitrail,
#               name=trail['properties']['TName'],
#               length_mi=trail['properties']['TLength_mi'],
#               status=trail['properties']['TStatus'],
#               display=display,
#               pubshare=pubshare,
#               gpsupdate=trail['properties']['GPSUpDate'],
#               gpsunit=trail['properties']['GPSUnit'],
#               gpsuser=trail['properties']['GPSUser'],
#               bspaid=trail['properties']['BSPAID'],
#               tsid=trail['properties']['TSID'],
#               display_wu=display_wu,
#               display_wn=display_wn,
#               ttype=trail['properties']['TType'],
#               season=trail['properties']['TSeason'],
#               shape_leng=trail['properties']['Shape_Leng'],
#               tclass=trail['properties']['TClass'],
#               maintclass=trail['properties']['MaintClass'],
#               slength=trail['properties']['SLength'],
#               min_slope=trail['properties']['Min_Slope'],
#               max_slope=trail['properties']['Max_Slope'],
#               avg_slope=trail['properties']['Avg_Slope'],
#               length_ft=trail['properties']['TLength_ft'])
#     return t

# %%
def trail_maker(trail):
    if trail['properties']['SkiTrail'] == 'Y':
        skitrail = True
    else:
        skitrail = False

    if trail['properties']['Display1'] == 'Y':
        display = True
    else:
        display = False

    if trail['properties']['PubShare'] == 'Y':
        pubshare = True
    else:
        pubshare = False

    if trail['properties']['Display_WU'] == 'Y':
        display_wu = True
    else:
        display_wu = False

    if trail['properties']['Display_WN'] == 'Y':
        display_wn = True
    else:
        display_wn = False
    t = Trail(geom=shape(trail['geometry']),
              use_type=trail['properties']['USE_TYPE'],
              comments=trail['properties']['COMMENTS'],
              tid=trail['properties']['TID'],
              skitrail=skitrail,
              name=trail['properties']['TName'],
              length_mi=trail['properties']['TLength_mi'],
              status=trail['properties']['TStatus'],
              display=display,
              pubshare=pubshare,
              gpsupdate=trail['properties']['GPSUpDate'],
              gpsunit=trail['properties']['GPSUnit'],
              gpsuser=trail['properties']['GPSUser'],
              bspaid=trail['properties']['BSPAID'],
              tsid=trail['properties']['TSID'],
              display_wu=display_wu,
              display_wn=display_wn,
              ttype=trail['properties']['TType'],
              season=trail['properties']['TSeason'],
              shape_leng=trail['properties']['Shape_Leng'],
              tclass=trail['properties']['TClass'],
              maintclass=trail['properties']['MaintClass'],
              slength=trail['properties']['SLength'],
              min_slope=trail['properties']['Min_Slope'],
              max_slope=trail['properties']['Max_Slope'],
              avg_slope=trail['properties']['Avg_Slope'],
              length_ft=trail['properties']['TLength_ft'])
    return t

# %%
with collection("BSP_Trails_2014Jan2.shp", "r") as input:
    for trail in input:
        print trail['geometry']['type']
# Out:
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# MultiLineString
# MultiLineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString

# %%
with collection("BSP_Trails_2014Jan2.shp", "r") as input:
    for trail in input:
        t = trail_maker(trail)

# %%
with collection("BSP_Trails_2014Jan2.shp", "r") as input:
    for trail in input:
        
        if trail['properties']['SkiTrail'] == 'Y':
            skitrail = True
        else:
            skitrail = False
            
        if trail['properties']['Display1'] == 'Y':
            display = True
        else:
            display = False
        
        if trail['properties']['PubShare'] == 'Y':
            pubshare = True
        else:
            pubshare = False
        
        if trail['properties']['Display_WU'] == 'Y':
            display_wu = True
        else:
            display_wu = False
        
        if trail['properties']['Display_WN'] == 'Y':
            display_wn = True
        else:
            display_wn = False
        
        print trail['properties']['TName']
        
        t = Trail(geom=shape(trail['geometry']),
                  use_type=trail['properties']['USE_TYPE'],
                  comments=trail['properties']['COMMENTS'],
                  tid=trail['properties']['TID'],
                  skitrail=skitrail,
                  name=trail['properties']['TName'],
                  length_mi=trail['properties']['TLength_mi'],
                  status=trail['properties']['TStatus'],
                  display=display,
                  pubshare=pubshare,
                  gpsupdate=trail['properties']['GPSUpDate'],
                  gpsunit=trail['properties']['GPSUnit'],
                  gpsuser=trail['properties']['GPSUser'],
                  bspaid=trail['properties']['BSPAID'],
                  tsid=trail['properties']['TSID'],
                  display_wu=display_wu,
                  display_wn=display_wn,
                  ttype=trail['properties']['TType'],
                  season=trail['properties']['TSeason'],
                  shape_leng=trail['properties']['Shape_Leng'],
                  tclass=trail['properties']['TClass'],
                  maintclass=trail['properties']['MaintClass'],
                  slength=trail['properties']['SLength'],
                  min_slope=trail['properties']['Min_Slope'],
                  max_slope=trail['properties']['Max_Slope'],
                  avg_slope=trail['properties']['Avg_Slope'],
                  length_ft=trail['properties']['TLength_ft'])
        db.session.add(t)
        db.session.commit()
# Out:
# Horse Mtn
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-4946f985a7df> in <module>()
#      56                   avg_slope=trail['properties']['Avg_Slope'],
#      57                   length_ft=trail['properties']['TLength_ft'])
# ---> 58         db.session.add(t)
#      59         db.session.commit()
#
# /usr/local/lib/python2.7/site-packages/sqlalchemy/orm/scoping.pyc in do(self, *args, **kwargs)
#     148 def instrument(name):
#     149     def do(self, *args, **kwargs):
# --> 150         return getattr(self.registry(), name)(*args, **kwargs)
#     151     return do
#     152
#
# /usr/local/lib/python2.7/site-packages/sqlalchemy/util/_collections.pyc in __call__(self)
#     876             return self.registry[key]
#     877         except KeyError:
# --> 878             return self.registry.setdefault(key, self.createfunc())
#     879
#     880     def has(self):
#
# /usr/local/lib/python2.7/site-packages/flask_sqlalchemy/__init__.pyc in create_session(self, options)
#     702         .. versionadded:: 2.0
#     703         """
# --> 704         return SignallingSession(self, **options)
#     705
#     706     def make_declarative_base(self):
#
# /usr/local/lib/python2.7/site-packages/flask_sqlalchemy/__init__.pyc in __init__(self, db, autocommit, autoflush, **options)
#     147     def __init__(self, db, autocommit=False, autoflush=True, **options):
#     148         #: The application that this session belongs to.
# --> 149         self.app = db.get_app()
#     150         self._model_changes = {}
#     151         #: A flag that controls whether this session should keep track of
#
# /usr/local/lib/python2.7/site-packages/flask_sqlalchemy/__init__.pyc in get_app(self, reference_app)
#     843         if ctx is not None:
#     844             return ctx.app
# --> 845         raise RuntimeError('application not registered on db '
#     846                            'instance and no application bound '
#     847                            'to current context')
#
# RuntimeError: application not registered on db instance and no application bound to current context
